# %%
import pandas as pd
df=pd.DataFrame()

# %%
df['Name']=['Hari','Priya']
df['Age']=['22','23']
df
# Out:
#     Name Age
# 0   Hari  22
# 1  Priya  23

# %%
new_row=pd.DataFrame([['Kavya','25']],columns=['Name','Age'])
df=pd.concat([df,new_row])
df
# Out:
#     Name Age
# 0   Hari  22
# 1  Priya  23
# 0  Kavya  25

# %%
print(df.shape)
print(df.info())
print(df.describe())
# Out:
# (3, 2)
# <class 'pandas.DataFrame'>
# Index: 3 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      str
#  1   Age     3 non-null      str
# dtypes: str(2)
# memory usage: 72.0 bytes
# None
#         Name Age
# count      3   3
# unique     3   3
# top     Hari  22
# freq       1   1

# %%
df1=df.drop('Age',axis=1)
df1
# Out:
#     Name
# 0   Hari
# 1  Priya
# 0  Kavya

# %%
df.iloc[0]
# Out:
# Name    Hari
# Age       22
# Name: 0, dtype: str

# %%
df['Age'] = ['22', '23', '25']

# %%
df
# Out:
#     Name Age
# 0   Hari  22
# 1  Priya  23
# 0  Kavya  25

# %%
df['Age'] = pd.to_numeric(df['Age'])
print(df[df['Age']>22])
# Out:
#     Name  Age
# 1  Priya   23
# 0  Kavya   25

# %%
print(df.sort_values(by='Age'))
# Out:
#     Name  Age
# 0   Hari   22
# 1  Priya   23
# 0  Kavya   25
